# %% [markdown]
# <a href="https://colab.research.google.com/github/josecontrerasu-bit/jicu/blob/main/00_Glosario(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
#
# 1. Divicion entera (`//`)
# > La divicion entre dos numeros en donde el resultado es simpre entero por tanto se redondea al entero menor
#
# ---
# 2. Expresiones
# > Es una coleccion de operadores y numeros
#
# ---
# 3. Valor
# > Resultado de una exprecion
#
# ---
# 4. Error SyntaxError
# > Ocure cuando llamo a una funcion y cometo un error en su escritura (por ejemplo abs 42, es una error, pues no puse los parentesis en el 42)
#
# ---
# 5. Duncion 'len()'
# >Cuenta la cantidad de caracteres que tiene un string. Si no pongo los parentesis tengo un error de sintaxis
#
# ---
# 6. Error de tipo (TypeError)
# >Ocurre cuando se ejecuta una operacion que no esta asociada a un tipo (Ejemplo: Dividir un string pues con string solo puedo * y /")
#
# ---
# 7. Debugging
